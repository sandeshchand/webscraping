# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeshchand/webscraping/blob/main/webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""webscrapping.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1ku91sTjTK3NPKcn6na9fYJMuQc8UI3j1
"""

import requests
import bs4
from bs4 import BeautifulSoup

url="https://economictimes.indiatimes.com/markets/stocks/news"

headers={
    'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36"
}

r=requests.get(url,{'headers':headers})

soup=bs4.BeautifulSoup(r.text,'html.parser')

soup.find_all('div',{'class':'eachStory'})[0].find_all('a')[-1].text

#headline plus descriptions
i=0
while i<10:
  headline=soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text
  print(str(i+1)+": "+headline)
  print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
  print()
  i+=1
# Out:
# 1: Finance Bill proposes amendments for enabling FPIs to subscribe to listed debt of REITs, InvITs
# REITs (Real Estate Investment Trusts) and InvITs (Infrastructure Investment Trusts) are relatively new investment instruments in the Indian context but are popular in global markets.
#
# 2: Sebi allows Thomas Cook India to withdraw Rs 150 crore share buyback offer
# Sebi said that if Thomas Cook is compelled to perform its share buyback programme, then it will have an adverse effect on its business and in turn, its shareholders.
#
# 3: Trade Setup: Correction overdue for Nifty; avoid high beta exposures
# Nifty would have ended flat once again, but for Reliance which contributed over 63 points out the 66.8-point gain.
#
# 4: NSE-BSE bulk deals: Ashoka Investment sells 0.6% stake in Majesco
# In a separate deal, India ACORN sold 628,000 shares of Majesco at Rs 62.15 apiece through a bulk deal on the NSE.
#
# 5: NSE disables Arcadia's trading terminals
# ...

# %%
# -*- coding: utf-8 -*-
"""Webscrappingwithcompany.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1dMJvUTWPVHtf2wTuA9ue2NtpNoLkxwAI
"""

import requests
import bs4
from bs4 import BeautifulSoup

headers={
    'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36"

}

r=requests.get(url,{'headers':headers})

soup=bs4.BeautifulSoup(r.text,'html.parser')

comp='facebook'
i=0
while i<10:
  url='https://www.dailypolitical.com/?s='+str(comp)
  r=requests.get(url,{'headers':headers})
  soup=bs4.BeautifulSoup(r.text,'html.parser')
  head=soup.find_all('div',{'class':'float-post-right'})[i].find_all('h2')[0].find_all('a')[-1].text
  print("headlines: "+head)
  desc=soup.find_all('div',{'class':'entry'})[i].find_all('p')[-1].text
  print("Descriptions: "+desc)
  print()
  i+=1

def getnews():
  comp='AMZN'
  i=0
  while i<20:
    

    url='https://www.marketbeat.com/stocks/NASDAQ/'+str(comp)+'/news'
    
    r=requests.get(url,{'headers':headers})
    soup=bs4.BeautifulSoup(r.text,'html.parser')
    print(soup.find('div',{'id':'dvHeadlines'}).find_all('a')[i].text)
    i+=1

getnews()
# Out:
# headlines: Pettyjohn Wood & White Inc. Has $1.70 Million Stock Position in Facebook, Inc. (NASDAQ:FB)
# Descriptions: Pettyjohn Wood & White Inc. reduced its stake in Facebook, Inc. (NASDAQ:FB) by 4.5% during the fourth quarter, according to the company in its most recent disclosure with the Securities and Exchange Commission (SEC). The firm owned 6,223 shares of the social networking company’s stock after selling 295 shares during the quarter. Pettyjohn Wood & […]
